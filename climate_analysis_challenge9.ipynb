# %%
# Import Dependencies

# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import extract
from sqlalchemy import create_engine, func

# %%
# Prepare database file to be connected to
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
# reflect an existing database into a new model - or transfer contents of dB into new data structure 
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB allowing us to query the data
session = Session(engine)

# %% [raw]
# # Extract June and Dec Data from Database

# %%
# Design a query to retrieve precipitation data for all years but only month of June.  
# Extract all transactions for month of 'June'

june_results = []
june_results = session.query(Measurement.date, Measurement.prcp).filter(extract('month', Measurement.date)=='06').all()

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
df1 = pd.DataFrame(june_results, columns=['date','precipitation'])
df1.set_index(df1['date'], inplace=True)
 
# Sort the dataframe by date
june_df = df1.sort_index()

# Convert dataframe to strings and suppress printing the index (which is the first data column)
print(june_df.to_string(index=False))
# Out:
#        date  precipitation
#  2010-06-01           0.00
#  2010-06-01           0.01
#  2010-06-01           0.00
#  2010-06-01            NaN
#  2010-06-01           0.03
#  2010-06-01           0.00
#  2010-06-01           0.00
#  2010-06-01           0.08
#  2010-06-01           0.03
#  2010-06-02           0.00
#  2010-06-02           0.03
#  2010-06-02           0.00
#  2010-06-02           0.00
#  2010-06-02           0.03
#  2010-06-02           0.00
#  2010-06-02           0.00
#  2010-06-02           0.00
#  2010-06-02           0.01
#  2010-06-03           0.00
#  2010-06-03           0.00
#  2010-06-03           0.10
#  2010-06-03           0.00
#  2010-06-03           0.14
#  2010-06-03           0.00
#  2010-06-03           0.00
#  2010-06-03           0.00
#  2010-06-03           0.00
#  2010-06-04           0.00
#  2010-06-04           0.00
#  2010-06-04           0.00
#  2010-06-04           0.00
#  2010-06-04           0.00
#  2010-06-04           0.01
# ...

# %%
# Design a query to retrieve precipitation data for all years but only month of Dec.  

dec_results = []
dec_results = session.query(Measurement.date, Measurement.prcp).filter(extract('month', Measurement.date)=='12').all()

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
df2 = pd.DataFrame(dec_results, columns=['date','precipitation'])
df2.set_index(df2['date'], inplace=True)

# print (df) 
# Sort the dataframe by date
dec_df = df2.sort_index()

# Convert dataframe to strings and suppress printing the index (which is the first data column)
print(dec_df.to_string(index=False))
# Out:
#        date  precipitation
#  2010-12-01           0.04
#  2010-12-01           0.03
#  2010-12-01           0.70
#  2010-12-01           0.03
#  2010-12-01           1.35
#  2010-12-01           0.13
#  2010-12-01           1.48
#  2010-12-01           0.76
#  2010-12-02            NaN
#  2010-12-02           0.16
#  2010-12-02           0.06
#  2010-12-02           0.26
#  2010-12-02           0.00
#  2010-12-02           0.13
#  2010-12-02           0.02
#  2010-12-02           0.18
#  2010-12-03           1.59
#  2010-12-03           0.01
#  2010-12-03           0.78
#  2010-12-03           0.00
#  2010-12-03           0.22
#  2010-12-03           0.01
#  2010-12-03           0.47
#  2010-12-03           0.16
#  2010-12-04           0.00
#  2010-12-04           0.00
#  2010-12-04           0.19
#  2010-12-04           0.00
#  2010-12-04           0.00
#  2010-12-04           0.00
#  2010-12-04           0.00
#  2010-12-05           0.00
#  2010-12-05           0.00
# ...

# %%
# Generate statistical functions on the precipitation data using the descibe function
june_df.describe()
# Out:
#        precipitation
# count    1574.000000
# mean        0.136360
# std         0.335731
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.120000
# max         4.430000

# %%
# Generate statistical functions on the precipitation data using the descibe function
dec_df.describe()
# Out:
#        precipitation
# count    1405.000000
# mean        0.216819
# std         0.541399
# min         0.000000
# 25%         0.000000
# 50%         0.030000
# 75%         0.150000
# max         6.420000

# %%
# Using the station with the highest number of temperature observations.
# Query all June temperature observation data for this station and plot the results as a histogram
results = session.query(Measurement.tobs).\
filter(Measurement.station == 'USC00519281').\
filter(extract('month', Measurement.date)=='06').all()
# filter(Measurement.date >= prev_year).all()
# print(results)  # line of code for debugging
df = pd.DataFrame(results, columns=['tobs'])
# print(df)  # used for debugging 

df.plot.hist(bins=10)
plt.tight_layout()

# %%
# Using the station with the highest number of temperature observations.
# Query all Dec temperature observation data for this station and plot the results as a histogram
results = session.query(Measurement.tobs).\
filter(Measurement.station == 'USC00519281').\
filter(extract('month', Measurement.date)=='12').all()
# filter(Measurement.date >= prev_year).all()
# print(results)  # line of code for debugging
df = pd.DataFrame(results, columns=['tobs'])
# print(df)  # used for debugging 

df.plot.hist(bins=10)
plt.tight_layout()
